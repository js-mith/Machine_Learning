# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
digit= datasets.load_digits()

# %%
digit.data.shape
# Out:
# (1797, 64)

# %%
fig = plt.figure(figsize=(8,8))
for i in range(64):
    ax = fig.add_subplot(8,8,i+1)
    ax.imshow(digit.images[i] ,cmap = plt.cm.bone)
plt.show()

# %%
x = digit.data
pca = PCA()
pca.fit(x)
pca.components_.shape
# Out:
# (64, 64)

# %%
k = 0
total = sum(pca.explained_variance_)
currsum = 0
while currsum/total < 0.99:
    currsum += pca.explained_variance_[k]
    k=k+1
k
# Out:
# 41

# %%
pca2 = PCA(n_components = k,whiten = True)
x_data = pca2.fit_transform(x)
x_data.shape
# Out:
# (1797, 41)

# %%
x_approx = pca2.inverse_transform(x_data)
x_approx.shape
# Out:
# (1797, 64)

# %%
x_approx_images = x_approx.reshape((1797,8,8))

# %%
fig = plt.figure(figsize=(8,8))
for i in range(64):
    ax = fig.add_subplot(8,8,i+1)
    ax.imshow(x_approx_images[i+30] ,cmap = plt.cm.bone)
plt.show()

# %%
eigenv = pca.components_
eigenv.shape
# Out:
# (64, 64)

# %%
eigenfaces = eigenv.reshape((64,8,8))

# %%
fig = plt.figure(figsize=(8,8))
for i in range(64):
    ax = fig.add_subplot(8,8,i+1)
    ax.imshow(eigenfaces[i] ,cmap = plt.cm.bone)
plt.show()
