# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
x1 = np.array([1,2,3,4,5,6])
x2 = np.array([7,5,11,16,18,20])

# %%
plt.scatter(x1,x2)
plt.show()

# %%
x = np.c_[x1,x2]
x
# Out:
# array([[ 1,  7],
#        [ 2,  5],
#        [ 3, 11],
#        [ 4, 16],
#        [ 5, 18],
#        [ 6, 20]])

# %%
pca = PCA(n_components =2)
x_transform = pca.fit_transform(x)
x_transform
# Out:
# array([[ 6.30165108, -0.75297503],
#        [ 7.93834427,  0.77058508],
#        [ 1.89992308,  0.03746193],
#        [-3.17910881, -0.41357581],
#        [-5.37997281, -0.01835733],
#        [-7.58083681,  0.37686116]])

# %%
pca.components_
# Out:
# array([[-0.28208541, -0.9593893 ],
#        [ 0.9593893 , -0.28208541]])

# %%
x_approx = pca.inverse_transform(x_transform)
x_approx
# Out:
# array([[ 1.,  7.],
#        [ 2.,  5.],
#        [ 3., 11.],
#        [ 4., 16.],
#        [ 5., 18.],
#        [ 6., 20.]])

# %%
plt.scatter(x_approx[:,0] , x_approx[:,1])
plt.show()
